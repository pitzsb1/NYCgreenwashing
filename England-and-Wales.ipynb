# %%
import pandas as pd
import os

base_path = "/Users/pitzsb1/Documents/all-domestic-certificates"

dfs = []

for folder in os.listdir(base_path):
    if "London" in folder:
        folder_path = os.path.join(base_path, folder)
        
        for file in os.listdir(folder_path):
            if file.endswith(".csv"):
                df = pd.read_csv(os.path.join(folder_path, file), nrows=100000)
                dfs.append(df)

df = pd.concat(dfs, ignore_index=True)
# Out:
# /var/folders/47/s6m8yv7s6xb1fh8qf9m8m2h00000gn/T/ipykernel_13664/4155963102.py:14: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(folder_path, file), nrows=100000)

# %%
import os

base_path = "/Users/pitzsb1/Documents/all-domestic-certificates"

print(os.listdir(base_path)[:5])
# Out:
# ['domestic-E07000133-Melton', 'domestic-E07000142-West-Lindsey', 'domestic-E08000019-Sheffield', 'domestic-E09000025-Newham', 'domestic-E07000150-Corby']

# %%
import os
import pandas as pd

base_path = "/Users/pitzsb1/Documents/all-domestic-certificates"

dfs = []

for folder in os.listdir(base_path):
    if folder.startswith("domestic-E09"):  # Entire London
        folder_path = os.path.join(base_path, folder)
        
        for file in os.listdir(folder_path):
            if file.endswith(".csv"):
                file_path = os.path.join(folder_path, file)
                df = pd.read_csv(file_path, nrows=50000, low_memory=False)
                dfs.append(df)

df = pd.concat(dfs, ignore_index=True)

print(df.shape)
# Out:
# (3222724, 99)

# %%
file_path = os.path.join(folder_path, "certificates.csv")

df = pd.read_csv(file_path, nrows=5000, low_memory=False)

df.head()
# Out:
#                                              LMK_KEY               ADDRESS1  \
# 0  20daddd4e5ce9abcca2efab2270af5bec902ad25059604...         30 Ditton Road
# 1                  348710630202009082415295465612048   Flat 17 Radley House
# 2                 1568897959442017082211075553339138     3, Palmar Crescent
# 3                  241356500262009022718093068038061        63, Ripley Road
# 4                  390808439262014031402084659128654  Flat 14 Orchard House
#
#           ADDRESS2 ADDRESS3  POSTCODE  BUILDING_REFERENCE_NUMBER  \
# 0              NaN      NaN   DA6 8JL                10003624703
# 1  Wolvercote Road      NaN   SE2 9TW                 6240736668
# 2              NaN      NaN   DA7 4LQ                 9440553578
# 3              NaN      NaN  DA17 5AH                 6635058568
# 4    Northend Road      NaN   DA8 3PY                 5537339668
#
#   CURRENT_ENERGY_RATING POTENTIAL_ENERGY_RATING  CURRENT_ENERGY_EFFICIENCY  \
# ...
